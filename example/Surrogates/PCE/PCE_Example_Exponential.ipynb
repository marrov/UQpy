# %% [markdown]
# ### Polynomial Chaos Expansion example: Exponential function (3 random inputs, scalar output)

# %% [markdown]
# Authors: Katiana Kontolati, Dimitrios Loukrezis \
# Date: May 7, 2021

# %% [markdown]
# In this example, PCE is used to generate a surrogate model for a given set of 3D data.

# %% [markdown]
# ### Dette & Pepelyshev exponential function

# %% [markdown]
# $$ f(x) = 100(\exp{(-2/x_1^{1.75})} + \exp{(-2/x_2^{1.5})} + \exp{(-2/x_3^{1.25})})$$
#
# **Description:**  Dimensions: 3
#
# **Input Domain:**  This function is evaluated on the hypercube $x_i \in [0,1]$ for all i = 1,2,3.
#
# **Reference:**  Dette, H., & Pepelyshev, A. (2010). Generalized Latin hypercube design for computer experiments. Technometrics, 52(4).

# %% [markdown]
# Import necessary libraries.

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from UQpy.Distributions import Uniform, JointInd
from UQpy.Surrogates import *

# %% [markdown]
# Define the function.

# %%
def function(x):
    return 100*(np.exp(-2/(x[:,0]**1.75)) + np.exp(-2/(x[:,1]**1.5)) + np.exp(-2/(x[:,2]**1.25)))

# %% [markdown]
# Define the input probability distributions.

# %%
# input distributions
dist = Uniform(loc=0, scale=1)   
marg = [dist]*3
joint = JointInd(marginals=marg)

# %% [markdown]
# Compute reference mean and variance values using Monte Carlo sampling.

# %%
# reference moments via Monte Carlo Sampling
n_samples_mc = 1000000
xx = joint.rvs(n_samples_mc)
yy = function(xx)
mean_ref = yy.mean()
var_ref = yy.var()

# %% [markdown]
# Create validation data sets, to be used later to estimate the accuracy of the PCE.

# %%
# validation data sets
n_samples_val = 1000
xx_val = joint.rvs(n_samples_val)
yy_val = function(xx_val)

# %% [markdown]
# Assess the PCE in terms of approximation and moment estimation accuracy, for increasing maximum polynomial degree.

# %%
# construct PCE surrogate models
l2_err = []
mean_err = []
var_err = []
for max_degree in range(1,10):
    print(' ')
    
    # PCE basis
    print('Total degree: ', max_degree)
    pce_metamodel = PolyChaosExp(joint)
    construct_td_basis(pce_metamodel, max_degree)
    print('Size of basis:', pce_metamodel.n_polys)
    
    # generate training data
    sampling_coeff = 5
    print('Sampling coefficient: ', sampling_coeff)
    np.random.seed(42)
    n_samples = math.ceil(sampling_coeff*pce_metamodel.n_polys)
    print('Training data: ', n_samples)
    xx_train = joint.rvs(n_samples)
    yy_train = function(xx_train)
    
    # fit model
    fit_lstsq(pce_metamodel, xx_train, yy_train)
    
    # validation errors
    yy_val_pce = pce_metamodel.predict(xx_val)
    errors = np.abs(yy_val - yy_val_pce.flatten())
    error_l2 = np.linalg.norm(errors)
    l2_err.append(error_l2)
    print('Validation error in the l2 norm:', error_l2)
    
    # moment errors
    mean_pce = pce_mean(pce_metamodel)
    var_pce = pce_variance(pce_metamodel)
    mean_err.append(np.abs((mean_pce - mean_ref)/mean_ref))
    var_err.append(np.abs((var_pce - var_ref)/var_ref))
    print('Relative error in the mean:', mean_err[-1])
    print('Relative error in the variance:', var_err[-1])
# Out:
#
# Total degree:  1
# Size of basis: 4
# Sampling coefficient:  5
# Training data:  20
# Validation error in the l2 norm: 129.7064596936069
# Relative error in the mean: [0.06746476]
# Relative error in the variance: [0.19436837]
#
# Total degree:  2
# Size of basis: 10
# Sampling coefficient:  5
# Training data:  50
# Validation error in the l2 norm: 32.59976216145259
# Relative error in the mean: [0.00592001]
# Relative error in the variance: [0.02178995]
#
# Total degree:  3
# Size of basis: 20
# Sampling coefficient:  5
# Training data:  100
# Validation error in the l2 norm: 11.335875925469718
# Relative error in the mean: [0.00396374]
# Relative error in the variance: [0.02870377]
#
# Total degree:  4
# Size of basis: 35
# Sampling coefficient:  5
# Training data:  175
# Validation error in the l2 norm: 6.547842621453174
# Relative error in the mean: [0.00108224]
# Relative error in the variance: [0.00322666]
#
# Total degree:  5
# Size of basis: 56
# Sampling coefficient:  5
# Training data:  280
# Validation error in the l2 norm: 2.0737637601847667
# Relative error in the mean: [0.00176938]
# Relative error in the variance: [0.00274329]
#
# Total degree:  6
# Size of basis: 84
# Sampling coefficient:  5
# Training data:  420
# Validation error in the l2 norm: 1.4600119004725545
# Relative error in the mean: [0.00114981]
# Relative error in the variance: [0.00420911]
#
# Total degree:  7
# Size of basis: 120
# Sampling coefficient:  5
# Training data:  600
# Validation error in the l2 norm: 0.7066078568724978
# Relative error in the mean: [0.00085017]
# Relative error in the variance: [0.00116549]
#
# Total degree:  8
# Size of basis: 165
# Sampling coefficient:  5
# Training data:  825
# Validation error in the l2 norm: 0.3345646801413434
# Relative error in the mean: [0.00096872]
# Relative error in the variance: [0.0018144]
#
# Total degree:  9
# Size of basis: 220
# Sampling coefficient:  5
# Training data:  1100
# Validation error in the l2 norm: 0.14690946551039677
# Relative error in the mean: [0.00092161]
# Relative error in the variance: [0.00194934]
